# %% [markdown]
# <a href="https://colab.research.google.com/github/Meaiie/python_dataviz2024/blob/main/Visualize_Data_Distribution_(02)_2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # การแสดงผลการกระจายของข้อมูล

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %% [markdown]
# ## Scatter 2D

# %% [markdown]
# ## scatter - default

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'])

# %% [markdown]
# ### color

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c='r')

# %% [markdown]
# ## ใส่สีให้แต่ละจุด

# %%
set(df['Name']) #ดูว่ามีค่าอะไรบ้าง
# Out:
# {'Iris-setosa', 'Iris-versicolor', 'Iris-virginica'}

# %%
df2 = df.replace({'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica':2})
df2
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth  Name
# 0            5.1         3.5          1.4         0.2     0
# 1            4.9         3.0          1.4         0.2     0
# 2            4.7         3.2          1.3         0.2     0
# 3            4.6         3.1          1.5         0.2     0
# 4            5.0         3.6          1.4         0.2     0
# ..           ...         ...          ...         ...   ...
# 145          6.7         3.0          5.2         2.3     2
# 146          6.3         2.5          5.0         1.9     2
# 147          6.5         3.0          5.2         2.0     2
# 148          6.2         3.4          5.4         2.3     2
# 149          5.9         3.0          5.1         1.8     2
#
# [150 rows x 5 columns]

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'])

# %% [markdown]
# ### alpha กำหนดความโปร่งแสง

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ใช้ขนาดของ marker แสดงค่าของ feature

# %%
plt.scatter(df['PetalLength'],df['SepalLength'],s=50*df['PetalWidth'],c=df2['Name'],alpha=0.5)

# %% [markdown]
# ## ตัวแปร Marker ใช้ในการเปลี่ยนหน้าตาของ marker

# %%
plt.scatter(df['PetalLength'],df['PetalWidth'],s=100,c=df2['Name'],alpha=0.5,marker='*')

# %% [markdown]
# ## การ plot กราฟหลายๆอันซ้อนกัน

# %%
plt.scatter(df['PetalLength'][:50],df['PetalWidth'][:50],s=100,c='m',alpha=0.5,marker='*')
plt.scatter(df['PetalLength'][50:100],df['PetalWidth'][50:100],s=100,c='c',alpha=0.5,marker='o')
plt.scatter(df['PetalLength'][100:],df['PetalWidth'][100:],s=100,c='r',alpha=0.5,marker='x')

# %% [markdown]
# ###Label-Legend

# %% [markdown]
# ```plt.plot()``` input  ตัวที่ 3 คือ ตัวกำหนดหน้าตาของ marker
#
# 'หน้าตาmarker'-'ลักษณะของเส้นเชื่อมจุด'-'สี'

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5)  # 'or' plot เป็น o , r คือสี red

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o-r',alpha=0.5) # plot o เส้นเชื่อม - ,red

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'o:r',alpha=0.5)

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='virginica')
plt.legend(loc='lower right') # ถ้าไม่กำหนด loc มันจะหา location ที่ดีที่สุดให้

# %% [markdown]
# ### การใส่ชื่อกราฟ และชื่อแกน

# %%
plt.plot(df['PetalLength'][:50],df['PetalWidth'][:50],'or',alpha=0.5,label='setosa')
plt.plot(df['PetalLength'][50:100],df['PetalWidth'][50:100],'xc',alpha=0.5,label='versicolor')
plt.plot(df['PetalLength'][100:],df['PetalWidth'][100:],'*m',alpha=0.5,label='virginica')
plt.legend(loc='lower right')
plt.title('Iris flower data distribution') ##ชื่อกราฟ
plt.xlabel('PetalLength') ##ชื่อแกน X
plt.ylabel('PetalWidth'); ##ชื่อแกน y

# %% [markdown]
# ### 3D scatter

# %%
ax = plt.axes(projection ="3d")
ax.scatter3D(df['PetalLength'],df['PetalWidth'],df['SepalWidth'],c=df2['Name'])

# %% [markdown]
# ## Bubble Chart
#
# Scatter plot ที่ใช้ขนาดของ marker ในการสื่อปริมาณของข้อมูล

# %%
plt.scatter(df['PetalLength'][:50],df['SepalLength'][:50],s=180*df['PetalWidth'][100:],c='c',alpha=0.5)

# %% [markdown]
# ### Box-plot

# %%
df = pd.read_csv('https://raw.github.com/pandas-dev/pandas/master/pandas/tests/io/data/csv/iris.csv')
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth         Name
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
O = plt.boxplot(df['SepalWidth'])

# %%
O # fliers คือ outlier
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7efc487a0f40>,
#   <matplotlib.lines.Line2D at 0x7efc487a11e0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7efc487a1480>,
#   <matplotlib.lines.Line2D at 0x7efc487a1720>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7efc487a0ca0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7efc487a19c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7efc487a1c60>],
#  'means': []}

# %%
O['fliers'][0].get_ydata()
# Out:
# array([2. , 4.4, 4.1, 4.2])

# %%
O['fliers'][0]

# %%
dir(O['fliers'][0])
# Out:
# ['_PROPERTIES_EXCLUDED_FROM_SET',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_animated',
#  '_antialiased',
#  '_axes',
#  '_callbacks',
#  '_clipon',
#  '_clippath',
#  '_cm_set',
#  '_color',
#  '_dash_pattern',
#  '_dashcapstyle',
#  '_dashjoinstyle',
#  '_default_contains',
#  '_drawStyles_l',
#  '_drawStyles_s',
#  '_drawstyle',
#  '_fully_clipped_to_axes',
#  '_gapcolor',
#  '_get_markerfacecolor',
#  '_get_transformed_path',
#  '_gid',
#  '_in_layout',
#  '_internal_update',
#  '_invalidx',
#  '_invalidy',
#  '_is_sorted',
#  '_label',
#  '_lineStyles',
#  '_linestyle',
#  '_linestyles',
#  '_linewidth',
#  '_marker',
#  '_markeredgecolor',
#  '_markeredgewidth',
#  '_markerfacecolor',
#  '_markerfacecoloralt',
#  '_markersize',
#  '_markevery',
#  '_mouseover',
#  '_path',
#  '_path_effects',
#  '_picker',
#  '_pickradius',
#  '_rasterized',
#  '_remove_method',
#  '_set_alpha_for_array',
#  '_set_gc_clip',
#  '_set_markercolor',
#  '_sketch',
#  '_snap',
#  '_solidcapstyle',
#  '_solidjoinstyle',
#  '_stale',
#  '_sticky_edges',
#  '_subslice',
#  '_transform',
#  '_transformSet',
#  '_transform_path',
#  '_transformed_path',
#  '_unscaled_dash_pattern',
#  '_update_props',
#  '_update_set_signature_and_docstring',
#  '_url',
#  '_visible',
#  '_x',
#  '_x_filled',
#  '_xorig',
#  '_xy',
#  '_y',
#  '_yorig',
#  'add_callback',
#  'axes',
#  'clipbox',
#  'contains',
#  'convert_xunits',
#  'convert_yunits',
#  'draw',
#  'drawStyleKeys',
#  'drawStyles',
#  'figure',
#  'fillStyles',
#  'filled_markers',
#  'findobj',
#  'format_cursor_data',
#  'get_aa',
#  'get_agg_filter',
#  'get_alpha',
#  'get_animated',
#  'get_antialiased',
#  'get_bbox',
#  'get_c',
#  'get_children',
#  'get_clip_box',
#  'get_clip_on',
#  'get_clip_path',
#  'get_color',
#  'get_cursor_data',
#  'get_dash_capstyle',
#  'get_dash_joinstyle',
#  'get_data',
#  'get_drawstyle',
#  'get_ds',
#  'get_figure',
#  'get_fillstyle',
#  'get_gapcolor',
#  'get_gid',
#  'get_in_layout',
#  'get_label',
#  'get_linestyle',
#  'get_linewidth',
#  'get_ls',
#  'get_lw',
#  'get_marker',
#  'get_markeredgecolor',
#  'get_markeredgewidth',
#  'get_markerfacecolor',
#  'get_markerfacecoloralt',
#  'get_markersize',
#  'get_markevery',
#  'get_mec',
#  'get_mew',
#  'get_mfc',
#  'get_mfcalt',
#  'get_mouseover',
#  'get_ms',
#  'get_path',
#  'get_path_effects',
#  'get_picker',
#  'get_pickradius',
#  'get_rasterized',
#  'get_sketch_params',
#  'get_snap',
#  'get_solid_capstyle',
#  'get_solid_joinstyle',
#  'get_tightbbox',
#  'get_transform',
#  'get_transformed_clip_path_and_affine',
#  'get_url',
#  'get_visible',
#  'get_window_extent',
#  'get_xdata',
#  'get_xydata',
#  'get_ydata',
#  'get_zorder',
#  'have_units',
#  'ind_offset',
#  'is_dashed',
#  'is_transform_set',
#  'lineStyles',
#  'markers',
#  'mouseover',
#  'pchanged',
#  'pick',
#  'pickable',
#  'pickradius',
#  'properties',
#  'recache',
#  'recache_always',
#  'remove',
#  'remove_callback',
#  'set',
#  'set_aa',
#  'set_agg_filter',
#  'set_alpha',
#  'set_animated',
#  'set_antialiased',
#  'set_c',
#  'set_clip_box',
#  'set_clip_on',
#  'set_clip_path',
#  'set_color',
#  'set_dash_capstyle',
#  'set_dash_joinstyle',
#  'set_dashes',
#  'set_data',
#  'set_drawstyle',
#  'set_ds',
#  'set_figure',
#  'set_fillstyle',
#  'set_gapcolor',
#  'set_gid',
#  'set_in_layout',
#  'set_label',
#  'set_linestyle',
#  'set_linewidth',
#  'set_ls',
#  'set_lw',
#  'set_marker',
#  'set_markeredgecolor',
#  'set_markeredgewidth',
#  'set_markerfacecolor',
#  'set_markerfacecoloralt',
#  'set_markersize',
#  'set_markevery',
#  'set_mec',
#  'set_mew',
#  'set_mfc',
#  'set_mfcalt',
#  'set_mouseover',
#  'set_ms',
#  'set_path_effects',
#  'set_picker',
#  'set_pickradius',
#  'set_rasterized',
#  'set_sketch_params',
#  'set_snap',
#  'set_solid_capstyle',
#  'set_solid_joinstyle',
#  'set_transform',
#  'set_url',
#  'set_visible',
#  'set_xdata',
#  'set_ydata',
#  'set_zorder',
#  'stale',
#  'stale_callback',
#  'sticky_edges',
#  'update',
#  'update_from',
#  'zorder']

# %%
O['fliers'][0].get_ydata()
# Out:
# array([2. , 4.4, 4.1, 4.2])

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True)

# %%
O
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7efc487f1690>,
#   <matplotlib.lines.Line2D at 0x7efc487f1930>],
#  'caps': [<matplotlib.lines.Line2D at 0x7efc487f1bd0>,
#   <matplotlib.lines.Line2D at 0x7efc487f1cc0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7efc487f13f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7efc487f1f90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7efc487f24d0>],
#  'means': [<matplotlib.lines.Line2D at 0x7efc487f2230>]}

# %%
O = plt.boxplot(df['SepalWidth'],showmeans=True,meanline=True,vert=False)

# %% [markdown]
# # HW 7 plot กราฟ แสดง การกระจายของข้อมูลใน india imdb และมา Present เป็นกลุ่ม (2 กราฟ)

# %% [markdown]
# ## import ข้อมูล

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

path = '/content/drive/MyDrive/Data_viz'

#เซ็ท path ไปที่ folder ก่อน แล้วค่อยชี้ไปที่ไฟล์
movies_path = os.path.join(path,'IMDb Movies India.csv')

# %%
movie_df = pd.read_csv(movies_path, encoding='latin-1')
movie_df.head()
# Out:
#                                  Name    Year Duration            Genre  \
# 0                                         NaN      NaN            Drama
# 1  #Gadhvi (He thought he was Gandhi)  (2019)  109 min            Drama
# 2                         #Homecoming  (2021)   90 min   Drama, Musical
# 3                             #Yaaram  (2019)  110 min  Comedy, Romance
# 4                   ...And Once Again  (2010)  105 min            Drama
#
#    Rating Votes            Director       Actor 1             Actor 2  \
# 0     NaN   NaN       J.S. Randhawa      Manmauji              Birbal
# 1     7.0     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande
# 2     NaN   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur
# 3     4.4    35          Ovais Khan       Prateik          Ishita Raj
# 4     NaN   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta
#
#            Actor 3
# 0  Rajendra Bhatia
# 1    Arvind Jangid
# 2       Roy Angana
# 3  Siddhant Kapoor
# 4      Antara Mali

# %% [markdown]
# ## Data cleansing

# %%
movie_df['Year'] = movie_df['Year'].str.replace('(', '').str.replace(')', '')
movie_df.head()
# Out:
#                                  Name  Year Duration            Genre  Rating  \
# 0                                       NaN      NaN            Drama     NaN
# 1  #Gadhvi (He thought he was Gandhi)  2019  109 min            Drama     7.0
# 2                         #Homecoming  2021   90 min   Drama, Musical     NaN
# 3                             #Yaaram  2019  110 min  Comedy, Romance     4.4
# 4                   ...And Once Again  2010  105 min            Drama     NaN
#
#   Votes            Director       Actor 1             Actor 2          Actor 3
# 0   NaN       J.S. Randhawa      Manmauji              Birbal  Rajendra Bhatia
# 1     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande    Arvind Jangid
# 2   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur       Roy Angana
# 3    35          Ovais Khan       Prateik          Ishita Raj  Siddhant Kapoor
# 4   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta      Antara Mali

# %%
movie_df['Duration'] = movie_df['Duration'].str.replace('min', '')
movie_df.head()
# Out:
#                                  Name  Year Duration            Genre  Rating  \
# 0                                       NaN      NaN            Drama     NaN
# 1  #Gadhvi (He thought he was Gandhi)  2019     109             Drama     7.0
# 2                         #Homecoming  2021      90    Drama, Musical     NaN
# 3                             #Yaaram  2019     110   Comedy, Romance     4.4
# 4                   ...And Once Again  2010     105             Drama     NaN
#
#   Votes            Director       Actor 1             Actor 2          Actor 3
# 0   NaN       J.S. Randhawa      Manmauji              Birbal  Rajendra Bhatia
# 1     8       Gaurav Bakshi  Rasika Dugal      Vivek Ghamande    Arvind Jangid
# 2   NaN  Soumyajit Majumdar  Sayani Gupta   Plabita Borthakur       Roy Angana
# 3    35          Ovais Khan       Prateik          Ishita Raj  Siddhant Kapoor
# 4   NaN        Amol Palekar  Rajat Kapoor  Rituparna Sengupta      Antara Mali

# %% [markdown]
# ## Graph 1

# %%
movie_df['Genre'].value_counts()
# Out:
# Genre
# Drama                         2780
# Action                        1289
# Thriller                       779
# Romance                        708
# Drama, Romance                 524
#                               ...
# Action, Musical, War             1
# Horror, Crime, Thriller          1
# Animation, Comedy                1
# Romance, Action, Crime           1
# Adventure, Fantasy, Sci-Fi       1
# Name: count, Length: 485, dtype: int64

# %%
genres_list = [
    'Action', 'Adventure', 'Animation', 'Biography', 'Comedy',
    'Crime', 'Documentary', 'Drama', 'Family', 'Fantasy',
    'History', 'Horror', 'Musical', 'Mystery', 'Romance',
    'Sci-Fi', 'Sport', 'Thriller', 'War', 'Western'
]

# %%
def split_genres(row):
  # Check if the genre value is a string before splitting
  if isinstance(row['Genre'], str):
    genres = row['Genre'].split(',')
    return [genre.strip() for genre in genres]
  else:
    # Handle cases where the genre is not a string (e.g., return an empty list or NaN)
    return []

movie_df['Genre'] = movie_df.apply(split_genres, axis=1)

# %%
movie_df
# Out:
#                                      Name  Year Duration              Genre  \
# 0                                           NaN      NaN            [Drama]
# 1      #Gadhvi (He thought he was Gandhi)  2019     109             [Drama]
# 2                             #Homecoming  2021      90    [Drama, Musical]
# 3                                 #Yaaram  2019     110   [Comedy, Romance]
# 4                       ...And Once Again  2010     105             [Drama]
# ...                                   ...   ...      ...                ...
# 15504                 Zulm Ko Jala Doonga  1988      NaN           [Action]
# 15505                               Zulmi  1999     129     [Action, Drama]
# 15506                           Zulmi Raj  2005      NaN           [Action]
# 15507                       Zulmi Shikari  1988      NaN           [Action]
# 15508                        Zulm-O-Sitam  1998     130     [Action, Drama]
#
#        Rating Votes            Director           Actor 1             Actor 2  \
# 0         NaN   NaN       J.S. Randhawa          Manmauji              Birbal
# 1         7.0     8       Gaurav Bakshi      Rasika Dugal      Vivek Ghamande
# 2         NaN   NaN  Soumyajit Majumdar      Sayani Gupta   Plabita Borthakur
# 3         4.4    35          Ovais Khan           Prateik          Ishita Raj
# 4         NaN   NaN        Amol Palekar      Rajat Kapoor  Rituparna Sengupta
# ...       ...   ...                 ...               ...                 ...
# 15504     4.6    11       Mahendra Shah  Naseeruddin Shah       Sumeet Saigal
# 15505     4.5   655          Kuku Kohli      Akshay Kumar      Twinkle Khanna
# 15506     NaN   NaN          Kiran Thej   Sangeeta Tiwari                 NaN
# 15507     NaN   NaN                 NaN               NaN                 NaN
# 15508     6.2    20        K.C. Bokadia        Dharmendra          Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3      Siddhant Kapoor
# 4          Antara Mali
# ...                ...
# 15504    Suparna Anand
# 15505      Aruna Irani
# 15506              NaN
# 15507              NaN
# 15508      Arjun Sarja
#
# [15509 rows x 10 columns]

# %%
import pandas as pd
from matplotlib import pyplot as plt
from google.colab import drive
import os

# Function to split genres and create new rows
def split_genres(row):
  if isinstance(row['Genre'], list):
    new_rows = []
    for i in range(len(row['Genre'])):
      new_row = row.copy()
      new_row['Genre'] = row['Genre'][i]
      new_rows.append(new_row)
    return new_rows
  else:
    return [row]

# Apply the function to split genres and create new rows
new_movie_df = pd.concat([pd.DataFrame(split_genres(row)) for _, row in movie_df.iterrows()], ignore_index=True)

# Filter out rows with genres not in the genres_list
new_movie_df = new_movie_df[new_movie_df['Genre'].isin(genres_list)]

# %%
new_movie_df
# Out:
#                                      Name  Year Duration    Genre  Rating  \
# 0                                           NaN      NaN    Drama     NaN
# 1      #Gadhvi (He thought he was Gandhi)  2019     109     Drama     7.0
# 2                             #Homecoming  2021      90     Drama     NaN
# 3                             #Homecoming  2021      90   Musical     NaN
# 4                                 #Yaaram  2019     110    Comedy     4.4
# ...                                   ...   ...      ...      ...     ...
# 23068                               Zulmi  1999     129     Drama     4.5
# 23069                           Zulmi Raj  2005      NaN   Action     NaN
# 23070                       Zulmi Shikari  1988      NaN   Action     NaN
# 23071                        Zulm-O-Sitam  1998     130    Action     6.2
# 23072                        Zulm-O-Sitam  1998     130     Drama     6.2
#
#       Votes            Director          Actor 1            Actor 2  \
# 0       NaN       J.S. Randhawa         Manmauji             Birbal
# 1         8       Gaurav Bakshi     Rasika Dugal     Vivek Ghamande
# 2       NaN  Soumyajit Majumdar     Sayani Gupta  Plabita Borthakur
# 3       NaN  Soumyajit Majumdar     Sayani Gupta  Plabita Borthakur
# 4        35          Ovais Khan          Prateik         Ishita Raj
# ...     ...                 ...              ...                ...
# 23068   655          Kuku Kohli     Akshay Kumar     Twinkle Khanna
# 23069   NaN          Kiran Thej  Sangeeta Tiwari                NaN
# 23070   NaN                 NaN              NaN                NaN
# 23071    20        K.C. Bokadia       Dharmendra         Jaya Prada
# 23072    20        K.C. Bokadia       Dharmendra         Jaya Prada
#
#                Actor 3
# 0      Rajendra Bhatia
# 1        Arvind Jangid
# 2           Roy Angana
# 3           Roy Angana
# 4      Siddhant Kapoor
# ...                ...
# 23068      Aruna Irani
# 23069              NaN
# 23070              NaN
# 23071      Arjun Sarja
# 23072      Arjun Sarja
#
# [22970 rows x 10 columns]

# %%
new_movie_df['Genre'].value_counts()
# Out:
# Genre
# Drama          7243
# Action         3543
# Romance        2449
# Comedy         2029
# Thriller       1713
# Crime          1322
# Family          943
# Musical         589
# Adventure       541
# Horror          524
# Mystery         513
# Fantasy         458
# Documentary     383
# Biography       208
# History         207
# Animation       125
# Sport            70
# Sci-Fi           58
# War              47
# Western           5
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np

# Group the data by genre and count the occurrences
genre_counts = new_movie_df['Genre'].value_counts()

# Generate colors using a colormap (rainbow)
colors = plt.cm.rainbow(np.linspace(0, 1, len(genre_counts)))

# Set figure size for better readability
plt.figure(figsize=(10, 6))

# Create the line plot with rainbow colors
for i in range(len(genre_counts)):
    plt.plot(genre_counts.index[i:i+2], genre_counts.values[i:i+2], marker='o', color=colors[i], markersize=8, linewidth=2)

# Add labels and title with enhanced styling
plt.xlabel('Genre', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.title('Most Genres of movies', fontsize=16, fontweight='bold')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right', fontsize=12)

# Add gridlines for better visual guidance
plt.grid(True, linestyle='--', alpha=0.7)

# Display the plot
plt.tight_layout()  # Adjust layout to fit everything
plt.show()

# %% [markdown]
# ## Garph 2

# %%
movie_df = movie_df.dropna(subset=['Duration','Rating'])

# %%
movie_df['Duration'] = movie_df['Duration'].str.replace('min', '').astype(int)
movie_df['Year'] = pd.to_numeric(movie_df['Year'], errors='coerce')
# Out:
# <ipython-input-16-154598c5f6c4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['Duration'] = movie_df['Duration'].str.replace('min', '').astype(int)
# <ipython-input-16-154598c5f6c4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_df['Year'] = pd.to_numeric(movie_df['Year'], errors='coerce')

# %%
filtered_df = movie_df[(movie_df['Year'] >= 2000) & (movie_df['Year'] <= 2022)]

# %%
import seaborn as sns # Import the seaborn library and give it the alias 'sns'
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 10))
scatter_plot = sns.scatterplot(x='Duration', y='Rating', data=filtered_df,
                               s=100, edgecolor='w', alpha=0.7, palette='coolwarm', hue='Year')

plt.title('Scatter Plot of Duration vs. Rating (2000-2022)', fontsize=24)
plt.xlabel('Duration (minutes)', fontsize=18)
plt.ylabel('Rating', fontsize=18)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.legend(fontsize=14)
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()

# Calculate the mean duration and mean rating
mean_duration = filtered_df['Duration'].mean()
mean_rating = filtered_df['Rating'].mean()
plt.axhline(mean_rating, color='r', linestyle='--', linewidth=2, label=f'Mean Rating: {mean_rating:.2f}')
plt.axvline(mean_duration, color='g', linestyle='--', linewidth=2, label=f'Mean Duration: {mean_duration:.2f} min')

# Now use the calculated values in the plt.text function
plt.text(mean_duration+5, plt.ylim()[1]-0.5, f'Mean Duration: {mean_duration:.2f} min',color='g', fontsize=12)
plt.text(plt.xlim()[1]-50, mean_rating + 0.1, f'Mean Rating: {mean_rating:.2f}',color='g', fontsize=12)
# Out:
# Text(286.0, 5.854265778623532, 'Mean Rating: 5.75')
